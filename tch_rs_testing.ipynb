# %%
# Download libtorch 1.7.1 + Cuda11.0
# !wget https://download.pytorch.org/libtorch/cu110/libtorch-cxx11-abi-shared-with-deps-1.7.1%2Bcu110.zip
# !unzip libtorch-cxx11-abi-shared-with-deps-1.7.1+cu110.zip -d ~/
# Out:
# --2021-03-05 04:23:19--  https://download.pytorch.org/libtorch/cu110/libtorch-cxx11-abi-shared-with-deps-1.7.1%2Bcu110.zip
# Resolving download.pytorch.org (download.pytorch.org)... 13.32.204.34, 13.32.204.93, 13.32.204.49, ...
# Connecting to download.pytorch.org (download.pytorch.org)|13.32.204.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1095287689 (1.0G) [application/zip]
# Saving to: ‘libtorch-cxx11-abi-shared-with-deps-1.7.1+cu110.zip’
#
# libtorch-cxx11-abi- 100%[===================>]   1.02G  41.0MB/s    in 28s
#
# 2021-03-05 04:23:47 (37.2 MB/s) - ‘libtorch-cxx11-abi-shared-with-deps-1.7.1+cu110.zip’ saved [1095287689/1095287689]
#
# Archive:  libtorch-cxx11-abi-shared-with-deps-1.7.1+cu110.zip
#    creating: /root/libtorch/
#    creating: /root/libtorch/lib/
#   inflating: /root/libtorch/lib/libprocess_group_agent.so
#   inflating: /root/libtorch/lib/libtensorpipe_agent.so
#   inflating: /root/libtorch/lib/libtensorpipe.a
# ...

# %%
# Install Cargo and Rust
# !apt install -y cargo
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   gdb gdbserver libbabeltrace1 libc6-dbg libdw1 libstd-rust-1.47
#   libstd-rust-dev rust-gdb rustc
# Suggested packages:
#   cargo-doc gdb-doc rust-doc rust-src lld-11
# Recommended packages:
#   cargo
# The following NEW packages will be installed:
#   cargo gdb gdbserver libbabeltrace1 libc6-dbg libdw1 libstd-rust-1.47
#   libstd-rust-dev rust-gdb rustc
# 0 upgraded, 10 newly installed, 0 to remove and 29 not upgraded.
# Need to get 100 MB of archives.
# After this operation, 455 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdw1 amd64 0.170-0.4ubuntu0.1 [203 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libbabeltrace1 amd64 1.5.5-1 [154 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gdb amd64 8.1.1-0ubuntu1 [2,937 kB]
# ...

# %%
# Set environment variables
# %env LIBTORCH=/root/libtorch
# %env LD_LIBRARY_PATH=/root/libtorch/lib:/usr/lib64-nvidia
# Out:
# env: LIBTORCH=/root/libtorch
# env: LD_LIBRARY_PATH=/root/libtorch/lib:/usr/lib64-nvidia

# %%
# %cd ~/
# Out:
# /root

# %%
# !git clone https://github.com/kenkoooo/tch-rs-cuda-check.git
# %cd tch-rs-cuda-check
# Out:
# Cloning into 'tch-rs-cuda-check'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 11 (delta 2), reused 11 (delta 2), pack-reused 0
# Unpacking objects: 100% (11/11), done.
# /root/tch-rs-cuda-check

# %%
# !cat Cargo.toml
# Out:
# [package]
# name = "tch-rs-cuda-check"
# version = "0.1.0"
# authors = ["kenkoooo <kenkou.n@gmail.com>"]
# edition = "2018"
#
# # See more keys and their definitions at https://doc.rust-lang.org/cargo/reference/manifest.html
#
# [dependencies]
# tch = "0.3.1"

# %%
# !cat src/main.rs
# Out:
# fn main() {
#     println!("{:?}", tch::Device::cuda_if_available());
#     println!("{:?}", tch::Cuda::cudnn_is_available());
# }

# %%
# !cargo run --release
# Out:
#     Updating crates.io index
# ...
#   Downloaded bzip2 v0.3.3
#   Downloaded autocfg v1.0.1
#   Downloaded cfg-if v0.1.10
#   Downloaded byteorder v1.4.2
#   Downloaded cmake v0.1.45
#   Downloaded cc v1.0.66
#   Downloaded curl v0.4.34
#   Downloaded matrixmultiply v0.2.4
#   Downloaded num-complex v0.2.4
#   Downloaded zip v0.5.9
#   Downloaded openssl-sys v0.9.60
#   Downloaded socket2 v0.3.19
#   Downloaded num-integer v0.1.44
#   Downloaded crc32fast v1.2.1
#   Downloaded rand_chacha v0.2.2
#   Downloaded thiserror-impl v1.0.23
#   Downloaded unicode-xid v0.2.1
#   Downloaded quote v1.0.8
#   Downloaded time v0.1.44
#   Downloaded rand v0.7.3
#   Downloaded flate2 v1.0.14
#   Downloaded proc-macro2 v1.0.24
#   Downloaded tch v0.3.1
#   Downloaded syn v1.0.58
#   Downloaded libc v0.2.82
#   Downloaded miniz_oxide v0.3.7
#   Downloaded libz-sys v1.1.2
#   Downloaded bzip2-sys v0.1.9+1.0.8
#   Downloaded curl-sys v0.4.39+curl-7.74.0
#   Downloaded num-traits v0.2.14
# ...
